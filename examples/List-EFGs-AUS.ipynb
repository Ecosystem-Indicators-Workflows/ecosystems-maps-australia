# %%
import pyprojroot
import sys

# %%
repodir = pyprojroot.find_root(pyprojroot.has_dir(".git"))
sys.path.append(str(repodir))

# %%
data_dir = repodir / 'gisdata' / 'AUS' / 'NEAP'

# %%
data_dir
# Out:
# PosixPath('/Users/z3529065/proyectos/EIW/ecosystems-map-synthesis/gisdata/AUS/NEAP')

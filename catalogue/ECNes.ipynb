# %% [markdown]
# # Ecological Communities of National Environmental Significance

# %% [markdown]
# In this document we will use the spatial data of the [***Ecological Communities of National Environmental Significance Distributions***](https://fed.dcceew.gov.au/datasets/3ce27fab85194f468bcfb106e5be15ee/about) dataset provided by the Department of Climate Change, Energy, the Environment and Water in the Find Environmental Data geospatial catalogue.
#
# The instructions below provide all the steps to download the data and metadata from the catalogue and prepare it for further analysis.
#
# The input data is in a compressed Geodatabase (zipped GDB) format and is provided with a Creative Commons License ([CC BY 4.0](https://creativecommons.org/licenses/by/4.0)).
#
# We filter the data to extract the ecological community of interest and export this in Geopackage (GPKG) format.

# %% [markdown]
# ## Relative path

# %%
REPODIR=$(pwd)

# %%
export OUTPUT_DIR=$REPODIR/../gisdata/TEC
mkdir -p $OUTPUT_DIR

# %% [markdown]
# ## Download from data repository

# %%
wget --continue https://www.arcgis.com/sharing/rest/content/items/3ce27fab85194f468bcfb106e5be15ee/data --output-document=$OUTPUT_DIR/ECNes_public_gdb.zip
# Out:
# --2026-03-04 12:24:23--  https://www.arcgis.com/sharing/rest/content/items/3ce27fab85194f468bcfb106e5be15ee/data
# Resolving www.arcgis.com (www.arcgis.com)... 18.65.244.69, 18.65.244.68, 18.65.244.13, ...
# Connecting to www.arcgis.com (www.arcgis.com)|18.65.244.69|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# ...

# %% [markdown]
# Unzip data

# %%
unzip -u $OUTPUT_DIR/ECNes_public_gdb.zip -d $OUTPUT_DIR
# Out:
# Archive:  /Users/z3529065/proyectos/EIW/SA-fleurieu-landcover/ecosystem/../gisdata/TEC/ECNes_public_gdb.zip

# %% [markdown]
# ## Metadata

# %% [markdown]
# The downloaded zipfile does not include metadata, but this is available from the [FED website](https://www.arcgis.com/sharing/rest/content/items/3ce27fab85194f468bcfb106e5be15ee/info/metadata/metadata.xml?format=default).

# %%
URL="https://www.arcgis.com/sharing/rest/content/items/3ce27fab85194f468bcfb106e5be15ee/info/metadata/metadata.xml?format=default"

wget --continue $URL --output-document=$OUTPUT_DIR/metadata.xml
# Out:
# --2026-03-04 12:24:25--  https://www.arcgis.com/sharing/rest/content/items/3ce27fab85194f468bcfb106e5be15ee/info/metadata/metadata.xml?format=default
# Resolving www.arcgis.com (www.arcgis.com)... 18.65.244.69, 18.65.244.68, 18.65.244.13, ...
# Connecting to www.arcgis.com (www.arcgis.com)|18.65.244.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/xml]
# Saving to: ‘/Users/z3529065/proyectos/EIW/SA-fleurieu-landcover/ecosystem/../gisdata/TEC/metadata.xml’
#
# /Users/z3529065/pro     [ <=>                ]  52.64K  --.-KB/s    in 0.004s
#
# 2026-03-04 12:24:26 (13.3 MB/s) - ‘/Users/z3529065/proyectos/EIW/SA-fleurieu-landcover/ecosystem/../gisdata/TEC/metadata.xml’ saved [53906]

# %% [markdown]
#  After manual inspection I found that this file contains fields for purpose, abstract and credit. We can automatically query the downloaded file using `xmllint` and `xpath` expressions to extract this information. ^[Here is useful to add the `local-name()` to ignore the namespaces that would otherwise cause a "XPath set is empty" error.]

# %%
XPATH="////*[local-name()='purpose']/*[local-name()='CharacterString']/text()"
xmllint $OUTPUT_DIR/metadata.xml  --xpath $XPATH | fmt -w 80
# Out:
# The Ecological Communities of National Environmental Significance (ECNES)
# database contains spatial information on the indicative distribution of
# threatened ecological communities listed under the Environment Protection and
# Biodiversity Conservation Act 1999 (EPBC Act).&#13; &#13; The distributions are
# at 100m resolution (1km in WA) and show where Threatened Ecological Communities
# may or are likely to occur. The dataset includes Matters of National
# Environmental Significance (critically endangered and endangered) and vulnerable
# ecological communities.&#13;
#  &#13;
# This database is updated when new listings take effect.

# %%
XPATH="////*[local-name()='abstract']/*[local-name()='CharacterString']/text()"
xmllint $OUTPUT_DIR/metadata.xml  --xpath $XPATH | fmt -w 80
# Out:
# The indicative spatial distribution of these threatened ecological communities
# is based on geospatial mapping units (such as local and regional scale
# vegetation mapping) that best represent the species assemblage and area in
# nature that defines these ecological communities as described in the relevant
# Conservation Advice. These distributions should be considered as indicative
# rather than a definitive assessment of presence or absence of these ecological
# communities within a given area of interest. They are not intended for use at a
# local or regional scale and should not be used for absolute area calculations.
# They represent a starting point for further investigation rather than the
# outcome of a comprehensive scientific assessment. Ground truthing is required to
# verify if a particular site meets the diagnostic characteristics and minimum
# condition thresholds to be the described ecological community.The generalised
# ...

# %%
XPATH="////*[local-name()='credit']/*[local-name()='CharacterString']/text()"
xmllint $OUTPUT_DIR/metadata.xml  --xpath $XPATH | fmt -w 80
# Out:
# Citation: Ecological Communities of National Environmental Significance database
# () Department of Climate Change, Energy, the Environment and Water, Canberra. ©
# Commonwealth of Australia.&#13; &#13; The indicative distribution mapping for
# threatened ecological communities are often based on a broad range of source
# data and information at local, regional and national scales. These data and
# information are sourced primarily from Australian Government agencies (such as
# Geoscience Australia and the CSIRO), State and Territory government (such as
# environment, primary industries and planning agencies), National and State
# biodiversity collections (such as museums and herbaria), research institutions
# (such as universities and cooperative research centres) as well as local
# councils, independent experts, and First Nations custodians. Specific data
# sources and contributions to the distribution mapping for an ecological
# ...

# %% [markdown]
# ## Extract ecological community of interest

# %% [markdown]
# Now we want to extract the data for the target community. Here we use functions from the `gdal` library. First we use `ogrinfo` to get a list of all ecological communities in the dataset:

# %%
ogrinfo $OUTPUT_DIR/ECNes_public_gdb.gdb -sql "SELECT distinct COMMUNITY FROM ECnes_public where COMMUNITY like '%Fleurieu%'"
# Out:
# INFO: Open of `/Users/z3529065/proyectos/EIW/SA-fleurieu-landcover/ecosystem/../gisdata/TEC/ECNes_public_gdb.gdb'
#       using driver `OpenFileGDB' successful.
#
# Layer name: ECnes_public
# Geometry: None
# Feature Count: 1
# Layer SRS WKT:
# (unknown)
# COMMUNITY: String (254.0)
# OGRFeature(ECnes_public):0
#   COMMUNITY (String) = Swamps of the Fleurieu Peninsula

# %% [markdown]
# And now we extract it into a new vector file using `ogr2ogr`:

# %%
ogr2ogr $OUTPUT_DIR/Swamps-Fleurieu-IM.gpkg $OUTPUT_DIR/ECNes_public_gdb.gdb ECnes_public -where "COMMUNITY='Swamps of the Fleurieu Peninsula'" -nlt "MULTIPOLYGON" -makevalid
# Out:
# Warning 1: organizePolygons() received a polygon with more than 100 parts. The processing may be really slow.  You can skip the processing by setting METHOD=SKIP, or only make it analyze counter-clock wise parts by setting METHOD=ONLY_CCW if you can assume that the outline of holes is counter-clock wise defined

# %% [markdown]
# ## Ready for the next steps
#
# Let's check that we have the output that we need for the next steps:

# %%
ls -lah $OUTPUT_DIR
# Out:
# total 59592
# drwxr-xr-x   7 z3529065  staff   224B Mar  4 12:24 .
# drwxr-xr-x   4 z3529065  staff   128B Mar  3 14:56 ..
# drwxrwxrwx  61 z3529065  staff   1.9K Jan 22 10:29 ECNes_Public_gdb.gdb
# -rw-r--r--   1 z3529065  staff    29M Jan 22 11:34 ECNes_public_gdb.zip
# -rw-r--r--   1 z3529065  staff   324K Mar  4 12:24 Swamps-Fleurieu-IM.gpkg
# -rw-r--r--   1 z3529065  staff    96K Mar  3 12:02 Swamps-Fleurieu-IM_AOO.gpkg
# -rw-r--r--   1 z3529065  staff    53K Mar  3 11:35 metadata.xml
